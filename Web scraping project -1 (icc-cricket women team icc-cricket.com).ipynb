# %% [markdown]
# # Python program to scrape women cricket rankings from icc-cricket.com.

# %% [markdown]
# Top 10 ODI teams in women’s cricket along with the records for matches, points and rating

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
Cricket_team = []

for i in soup.find_all('span',class_="u-hide-phablet"):
    Cricket_team.append(i.text)
    
Cricket_team
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'Bangladesh',
#  'West Indies',
#  'Pakistan',
#  'Ireland',
#  'Sri Lanka',
#  'Zimbabwe',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Women_cricket_team = Cricket_team[0:10]
Women_cricket_team
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'Bangladesh',
#  'West Indies',
#  'Pakistan',
#  'Ireland',
#  'Sri Lanka']

# %%
Matche1 = []

for i in soup.find_all('td',class_="rankings-block__banner--matches"):
    Matche1.append(i.text)
    
Matche1
# Out:
# ['20']

# %%
Matches = []

for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    Matches.append(i.text)
    
Matches
# Out:
# ['21',
#  '2,580',
#  '21',
#  '2,474',
#  '22',
#  '2,221',
#  '24',
#  '2,342',
#  '5',
#  '475',
#  '21',
#  '1,801',
#  '19',
#  '1,304',
#  '5',
#  '240',
#  '5',
#  '233',
#  '8',
#  '0']

# %%
Match2 = Matche1 + Matches[0::2]
Match2
# Out:
# ['20', '21', '21', '22', '24', '5', '21', '19', '5', '5', '8']

# %%
Match = Match2[0:10]
Match
# Out:
# ['20', '21', '21', '22', '24', '5', '21', '19', '5', '5']

# %%
Point1 = []

for i in soup.find_all('td',class_="rankings-block__banner--points"):
    Point1.append(i.text)
    
Point1
# Out:
# ['3,263']

# %%
Point2 = Point1 + Matches[1::2]

# %%
Point = Point2[0:10]
Point
# Out:
# ['3,263',
#  '2,580',
#  '2,474',
#  '2,221',
#  '2,342',
#  '475',
#  '1,801',
#  '1,304',
#  '240',
#  '233']

# %%
Rating1 = []

for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    Rating1.append(i.text.replace('\n',''))
    
Rating1
# Out:
# ['                            163                            ']

# %%
Rating2 = []
for rating in Rating1:
    rating = rating.strip(" ")
    Rating2.append(rating)
    
Rating2
# Out:
# ['163']

# %%
Ratings = []

for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    Ratings.append(i.text)
    
Ratings
# Out:
# ['123', '118', '101', '98', '95', '86', '69', '48', '47', '0']

# %%
Rating = Rating2 + Ratings[0:9]
Rating
# Out:
# ['163', '123', '118', '101', '98', '95', '86', '69', '48', '47']

# %%
print(len(Women_cricket_team))
print(len(Match))
print(len(Point))
print(len(Rating))
# Out:
# 10
# 10
# 10
# 10

# %%
import pandas as pd
df = pd.DataFrame({'Top 10 women cricket teams':Women_cricket_team,'No. of Matches':Match,'Point':Point,'Rating':Rating})
df
# Out:
#   Top 10 women cricket teams No. of Matches  Point Rating
# 0                  Australia             20  3,263    163
# 1               South Africa             21  2,580    123
# 2                    England             21  2,474    118
# 3                      India             22  2,221    101
# 4                New Zealand             24  2,342     98
# 5                 Bangladesh              5    475     95
# 6                West Indies             21  1,801     86
# 7                   Pakistan             19  1,304     69
# 8                    Ireland              5    240     48
# 9                  Sri Lanka              5    233     47

# %% [markdown]
# Top 10 women’s ODI Batting players along with the records of their team and rating

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
Women_batting1 = []

for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    Women_batting1.append(i.text)
    
Women_batting1
# Out:
# ['Alyssa Healy']

# %%
Women_battings = []

for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    Women_battings.append(i.text.replace('\n',''))
    
Women_battings
# Out:
# ['Mithali Raj',
#  'Tammy Beaumont',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Lizelle Lee',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Laura Wolvaardt',
#  'Ellyse Perry',
#  'Natalie Sciver',
#  'Stafanie Taylor',
#  'Rachael Haynes',
#  'Heather Knight',
#  'Mignon du Preez',
#  'Deandra Dottin',
#  'Amelia Kerr',
#  'Suzie Bates',
#  'Sophie Devine',
#  'Harmanpreet Kaur',
#  'Deepti Sharma',
#  'Amy Jones',
#  'Fargana Hoque',
#  'Ashleigh Gardner',
#  'Aliya Riaz',
#  'Marizanne Kapp',
#  'Poonam Raut',
#  'Rumana Ahmed',
#  'Nahida Khan',
#  'Javeria Khan',
#  'Dane van Niekerk',
#  'Hayley Matthews',
#  'Maddie Green',
#  'Gaby Lewis',
#  'Danielle Wyatt',
#  'Nida Dar',
#  'Katherine Brunt',
#  'Chloe-Lesleigh Tryon',
#  'Lauren Winfield',
#  'Sune Luus',
#  'Tahlia McGrath',
#  'Laura Delany',
#  'Brooke Halliday',
#  'Katey Martin',
#  'Richa Ghosh',
#  'Umaima Sohail',
#  'Shafali Verma',
#  'Jess Jonassen',
#  'Lauren Down',
#  'Katie Perkins',
#  'Kycia Knight',
# ...

# %%
Women_batting = Women_batting1 + Women_battings[0:9]
Women_batting
# Out:
# ['Alyssa Healy',
#  'Mithali Raj',
#  'Tammy Beaumont',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Lizelle Lee',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Laura Wolvaardt',
#  'Ellyse Perry']

# %%
Team1 = []

for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    Team1.append(i.text.replace('\n',''))
    
Team1
# Out:
# ['AUS                    ']

# %%
Team2 = []
for team in Team1:
    team = team.strip(" ")
    Team2.append(team)
Team2
# Out:
# ['AUS']

# %%
Teams = []

for i in soup.find_all('span',class_="table-body__logo-text"):
    Teams.append(i.text.replace('\n',''))
    
Teams
# Out:
# ['IND',
#  'ENG',
#  'AUS',
#  'AUS',
#  'SA',
#  'NZ',
#  'IND',
#  'SA',
#  'AUS',
#  'ENG',
#  'WI',
#  'AUS',
#  'ENG',
#  'SA',
#  'WI',
#  'NZ',
#  'NZ',
#  'NZ',
#  'IND',
#  'IND',
#  'ENG',
#  'BAN',
#  'AUS',
#  'PAK',
#  'SA',
#  'IND',
#  'BAN',
#  'PAK',
#  'PAK',
#  'SA',
#  'WI',
#  'NZ',
#  'IRE',
#  'ENG',
#  'PAK',
#  'ENG',
#  'SA',
#  'ENG',
#  'SA',
#  'AUS',
#  'IRE',
#  'NZ',
#  'NZ',
#  'IND',
#  'PAK',
#  'IND',
#  'AUS',
#  'NZ',
#  'NZ',
#  'WI',
#  'IND',
#  'SA',
#  'PAK',
#  'IRE',
#  'AUS',
#  'WI',
#  'IND',
#  'BAN',
#  'SA',
#  'BAN',
#  'IND',
#  'WI',
#  'SA',
#  'WI',
#  'BAN',
#  'IND',
#  'IND',
#  'NZ',
#  'IRE',
#  'IND',
#  'SA',
#  'ZIM',
#  'ENG',
#  'ENG',
#  'BAN',
#  'PAK',
#  'BAN',
#  'NZ',
#  'IRE',
#  'AUS',
#  'ZIM',
#  'NZ',
#  'IRE',
#  'IND',
#  'IRE',
#  'PAK',
#  'IND',
#  'SA',
#  'ENG',
#  'WI',
#  'BAN',
#  'BAN',
#  'IND',
#  'ENG',
#  'IND',
#  'NZ',
#  'NZ',
#  'SA',
#  'IRE']

# %%
Team = Team2 + Teams[0:9]
Team
# Out:
# ['AUS', 'IND', 'ENG', 'AUS', 'AUS', 'SA', 'NZ', 'IND', 'SA', 'AUS']

# %%
Rating1 = []

for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    Rating1.append(i.text.replace('\n',''))
    
Rating1
# Out:
# ['749']

# %%
Ratings = []

for i in soup.find_all('td',class_="table-body__cell rating"):
    Ratings.append(i.text.replace('\n',''))
    
Ratings
# Out:
# ['735',
#  '707',
#  '706',
#  '705',
#  '702',
#  '700',
#  '666',
#  '661',
#  '661',
#  '657',
#  '655',
#  '640',
#  '629',
#  '620',
#  '616',
#  '576',
#  '564',
#  '544',
#  '535',
#  '534',
#  '530',
#  '512',
#  '509',
#  '504',
#  '496',
#  '485',
#  '476',
#  '458',
#  '457',
#  '451',
#  '448',
#  '442',
#  '438',
#  '438',
#  '425',
#  '422',
#  '416',
#  '414',
#  '414',
#  '405',
#  '393',
#  '392',
#  '380',
#  '372',
#  '369',
#  '351',
#  '346',
#  '339',
#  '337',
#  '336',
#  '327',
#  '325',
#  '320',
#  '318',
#  '315',
#  '314',
#  '313',
#  '300',
#  '291',
#  '283',
#  '279',
#  '276',
#  '266',
#  '262',
#  '259',
#  '257',
#  '250',
#  '249',
#  '248',
#  '244',
#  '244',
#  '242',
#  '238',
#  '237',
#  '235',
#  '233',
#  '231',
#  '229',
#  '228',
#  '223',
#  '221',
#  '218',
#  '217',
#  '211',
#  '207',
#  '206',
#  '206',
#  '206',
#  '204',
#  '203',
#  '203',
#  '203',
#  '202',
#  '202',
#  '199',
#  '199',
#  '198',
#  '195',
#  '193']

# %%
Rating = Rating1 + Ratings[0:9]
Rating
# Out:
# ['749', '735', '707', '706', '705', '702', '700', '666', '661', '661']

# %%
print(len(Women_batting))
print(len(Team))
print(len(Rating))
# Out:
# 10
# 10
# 10

# %%
import pandas as pd
df = pd.DataFrame({'Name of The Women Batting':Women_batting,'Team':Team,'Rating':Rating})
df
# Out:
#   Name of The Women Batting Team Rating
# 0              Alyssa Healy  AUS    749
# 1               Mithali Raj  IND    735
# 2            Tammy Beaumont  ENG    707
# 3               Meg Lanning  AUS    706
# 4               Beth Mooney  AUS    705
# 5               Lizelle Lee   SA    702
# 6         Amy Satterthwaite   NZ    700
# 7           Smriti Mandhana  IND    666
# 8           Laura Wolvaardt   SA    661
# 9              Ellyse Perry  AUS    661

# %% [markdown]
# Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" property="og:title"/>
# ...

# %%
Allrounder_1st = []

for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    Allrounder_1st.append(i.text)
    
Allrounder_1st
# Out:
# ['Ellyse Perry']

# %%
Allrounders = []

for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    Allrounders.append(i.text.replace('\n',''))
    
Allrounders
# Out:
# ['Natalie Sciver',
#  'Marizanne Kapp',
#  'Amelia Kerr',
#  'Deepti Sharma',
#  'Katherine Brunt',
#  'Jess Jonassen',
#  'Stafanie Taylor',
#  'Ashleigh Gardner',
#  'Hayley Matthews',
#  'Sophie Devine',
#  'Dane van Niekerk',
#  'Jhulan Goswami',
#  'Rumana Ahmed',
#  'Nida Dar',
#  'Sune Luus',
#  'Heather Knight',
#  'Sophie Ecclestone',
#  'Kate Cross',
#  'Shikha Pandey']

# %%
Allrounder = Allrounder_1st + Allrounders[0:9]
Allrounder
# Out:
# ['Ellyse Perry',
#  'Natalie Sciver',
#  'Marizanne Kapp',
#  'Amelia Kerr',
#  'Deepti Sharma',
#  'Katherine Brunt',
#  'Jess Jonassen',
#  'Stafanie Taylor',
#  'Ashleigh Gardner',
#  'Hayley Matthews']

# %%
Team_1st = []

for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    Team_1st.append(i.text.replace('\n',''))
    
Team_1st
# Out:
# ['AUS                    ']

# %%
Team1 = []
for team in Team_1st:
    team = team.strip(" ")
    Team1.append(team)
Team1
# Out:
# ['AUS']

# %%
Teams = []

for i in soup.find_all('span',class_="table-body__logo-text"):
    Teams.append(i.text.replace('\n',''))
    
Teams
# Out:
# ['ENG',
#  'SA',
#  'NZ',
#  'IND',
#  'ENG',
#  'AUS',
#  'WI',
#  'AUS',
#  'WI',
#  'NZ',
#  'SA',
#  'IND',
#  'BAN',
#  'PAK',
#  'SA',
#  'ENG',
#  'ENG',
#  'ENG',
#  'IND']

# %%
Team = Team1 + Teams[0:9]
Team
# Out:
# ['AUS', 'ENG', 'SA', 'NZ', 'IND', 'ENG', 'AUS', 'WI', 'AUS', 'WI']

# %%
Rating_1st = []

for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    Rating_1st.append(i.text.replace('\n',''))
    
Rating_1st
# Out:
# ['438']

# %%
Ratings = []

for i in soup.find_all('td',class_="table-body__cell rating"):
    Ratings.append(i.text.replace('\n',''))
    
Ratings
# Out:
# ['351',
#  '327',
#  '312',
#  '309',
#  '273',
#  '263',
#  '262',
#  '256',
#  '254',
#  '251',
#  '233',
#  '227',
#  '195',
#  '186',
#  '170',
#  '156',
#  '152',
#  '142',
#  '141']

# %%
Rating = Rating_1st + Ratings[0:9]
Rating
# Out:
# ['438', '351', '327', '312', '309', '273', '263', '262', '256', '254']

# %%
print(len(Allrounder))
print(len(Team))
print(len(Rating))
# Out:
# 10
# 10
# 10

# %%
import pandas as pd
df = pd.DataFrame({'Women all-rounder Crickter Name':Allrounder,'Team':Team,'Rating':Rating})
df
# Out:
#   Women all-rounder Crickter Name Team Rating
# 0                    Ellyse Perry  AUS    438
# 1                  Natalie Sciver  ENG    351
# 2                  Marizanne Kapp   SA    327
# 3                     Amelia Kerr   NZ    312
# 4                   Deepti Sharma  IND    309
# 5                 Katherine Brunt  ENG    273
# 6                   Jess Jonassen  AUS    263
# 7                 Stafanie Taylor   WI    262
# 8                Ashleigh Gardner  AUS    256
# 9                 Hayley Matthews   WI    254
